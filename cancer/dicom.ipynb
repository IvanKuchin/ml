# %%
import matplotlib.pyplot as plt
import pydicom
from pydicom.data import get_testdata_files

print(__doc__)

filename = get_testdata_files('CT_small.dcm')[0]
filename = "/docs/src/kt/1/IMG-0001-00118.dcm"
dataset = pydicom.dcmread(filename)

print()
print("Filename\t:", filename)
print("Storage type\t:", dataset.SOPClassUID)
print()

pat_name = dataset.PatientName
display_name = pat_name.family_name + ", " + pat_name.given_name
print("Patient's name\t:", display_name)
print("Patient id\t:", dataset.PatientID)
print("Modality\t:", dataset.Modality)
print("Study Date\t:", dataset.StudyDate)

if 'PixelData' in dataset:
    rows = int(dataset.Rows)
    cols = int(dataset.Columns)
    print("Image size\t: {rows:d} x {cols:d}, {size:d} bytes".format(
        rows=rows, cols=cols, size=len(dataset.PixelData)
    ))
    
    if 'PixelSpacing' in dataset:
        print("Pixel spacing\t:", dataset.PixelSpacing)
        
print("Slice location\t:", dataset.get('SliceLocation', "(missing)"))

plt.imshow(dataset.pixel_array, cmap=plt.cm.bone)
plt.show()
# Out:
# Automatically created module for IPython interactive environment
#
# Filename	: /docs/src/kt/1/IMG-0001-00118.dcm
# Storage type	: 1.2.840.10008.5.1.4.1.1.2
#
# Patient's name	: EFREMOV   SERGEY  ALEXEEVICH, VIPROMID370-85ML
# Patient id	: PL AMB
# Modality	: CT
# Study Date	: 20180620
# Image size	: 512 x 512, 524288 bytes
# Pixel spacing	: ['0.7109375', '0.7109375']
# Slice location	: -171.8

# %%
dataset.PixelData
# Out:
# b'&\x00!\x00\x0f\x00\x12\x00\x18\x00\x16\x00\x18\x00\x19\x00\r\x00\t\x00\x13\x00\x17\x00\x18\x00\x18\x00\x16\x00\x16\x00\x1c\x00\x1e\x00\x19\x00\x05\x00\x05\x00 \x00*\x00\x1f\x00\x19\x00\x0f\x00\x08\x00\x0f\x00\x11\x00\x10\x00\x1a\x00\x17\x00\x15\x00!\x00!\x00\x1f\x00$\x00\x17\x00\x06\x00\x0e\x00\x10\x00\x11\x00\x1d\x00\'\x00\x1f\x00\x1a\x00\x1d\x00\x1d\x00!\x00\x1d\x00\x16\x00\x06\x00\x08\x00\x1a\x00#\x00\x1a\x00\x0e\x00\x02\x00\x03\x00\x0c\x00\x11\x00\x1b\x00%\x00&\x00+\x00\x1b\x00\x0e\x00\x10\x00\x0f\x00\n\x00\x11\x00\x1b\x00\x1f\x00\x1b\x00\x1f\x00\x11\x00\x0f\x00\x1e\x00\x1f\x00\x11\x00\x12\x00 \x00&\x00\x1f\x00\x18\x00\x16\x00\x1d\x00\x16\x00\x07\x00\x04\x00\x1a\x00\x1d\x00\x08\x00\x08\x00\x0e\x00\x15\x00)\x00%\x00!\x00\x17\x00\r\x00\x0f\x00\x14\x00\x1a\x00 \x00\x17\x00\x11\x00\n\x00\x08\x00\x14\x00#\x00-\x00\x19\x00\x04\x00\x07\x00\r\x00\x16\x00(\x00\x1e\x00\x04\x00\x11\x00(\x00&\x00\x1d\x00\x14\x00\x19\x00\r\x00\x01\x00\x15\x00\x15\x00\x18\x00"\x00\x1f\x00\x17\x00\x1a\x00!\x00\x1c\x00\x12\x00\x08\x00\x02\x00\x07\x00\x1a\x00%\x00\x1a\x00\x16\x00\x18\x00\x14\x00\x17\x00\x13\x00\x1a\x00\x1f\x00$\x00#\x00\x17\x00\x17\x00\x13\x00\x08\x00\x12\x00\x17\x00\x0f\x00\x1b\x00"\x00!\x00\x17\x00\x19\x00\x1f\x00\x1a\x00\x12\x00\x18\x00%\x00\x1f\x00\x0b\x00\x0c\x00\x15\x00\x0f\x00\x13\x00\x19\x00\x1e\x00$\x00\x1b\x00\t\x00\x04\x00\x05\x00\x12\x00 \x00%\x00\'\x00\x1d\x00\x12\x00\x08\x00\x14\x00\x1f\x00!\x00 \x00\x17\x00\x14\x00\x0f\x00\x14\x00\x19\x00\x16\x00\x16\x00\x1b\x00\x13\x00\x0e\x00\x1e\x00#\x00\x19\x00\x10\x00\x10\x00\x16\x00\x1c\x00\x11\x00\n\x00\x0c\x00\x15\x00&\x00"\x00\x1f\x00!\x00\x1f\x00\x1a\x00\x15\x00\x07\x00\x00\x00\x0c\x00\x1c\x00\x1b\x00 \x00\x17\x00\x05\x00\x05\x00\x18\x00-\x00&\x00$\x00\x13\x00\x07\x00\x15\x00\x1d\x00\x17\x00\x12\x00\x1a\x00\x17\x00\r\x00\x10\x00\x1c\x00\x18\x00\x12\x00\x13\x00\x1f\x001\x00#\x00\x15\x00\x11\x00\x12\x00\x0c\x00\x16\x00\x0b\x00\x16\x00\x1e\x00\x16\x00\x14\x00\x14\x00\x1c\x00 \x00\x13\x00\x17\x00\x1b\x00\t\x00\x0b\x00\x0c\x00\x07\x00\x1a\x00$\x00&\x00\x16\x00\x16\x00\x1e\x00 \x00\x17\x00 \x00$\x00\x1a\x00\r\x00\x0b\x00\x13\x00%\x00\x1f\x00\x11\x00\t\x00\x07\x00\x0c\x00\x04\x00\x15\x00&\x00\'\x00\x06\x00\x12\x00$\x00\x15\x00\x17\x00%\x00&\x00\x11\x00\x02\x00\x05\x00\t\x00\x1e\x00!\x00+\x00!\x00\x10\x00\x13\x00\x16\x00\x19\x00\x1c\x00\r\x00\x00\x00\x1d\x00&\x00\t\x00\x07\x00\r\x00\x16\x00!\x00\x1d\x00\x12\x00\x15\x00"\x00#\x00\x19\x00\x0e\x00\x1c\x00\x1d\x00\x04\x00\x0b\x00 \x00\x1e\x00\x14\x00\x18\x00\'\x00\x0c\x00\x0f\x00\x1a\x00\x0c\x00\x17\x00\x18\x00\x16\x00\x1c\x00$\x00 \x00 \x00\x12\x00\x18\x00\x1d\x00!\x00\x10\x00\x00\x00\r\x00#\x00\x1b\x00\x1a\x00\x06\x00\x10\x00\x15\x00\x1b\x00!\x00\x14\x00\x13\x00\x16\x00\x15\x00\x1c\x00&\x00\x06\x00\x00\x00\n\x00&\x00(\x00\x17\x00\x0b\x00\x16\x00\x12\x00\x05\x00\x16\x00!\x00\x19\x00\x0c\x00\x0f\x00\x10\x00\x0b\x00\x08\x00\x00\x00\x0c\x00\x14\x00\x15\x00\x15\x00&\x009\x00\x1c\x00\x15\x00\x0b\x00\r\x00\x0f\x00\x0f\x00\x10\x00\n\x00\x18\x00#\x00#\x00 \x00\x03\x00\x01\x00%\x00!\x00\x07\x00\x12\x00\x15\x00\x07\x00\x1c\x00&\x00\r\x00\t\x00\r\x00\x1a\x00#\x00%\x00\x1c\x00\x0e\x00\x00\x00\r\x00$\x00\x0f\x00\x0c\x00\x17\x00\r\x00\x18\x00"\x00\r\x00\x07\x00\x10\x00\x1c\x00"\x00\x1c\x00\x11\x00\x07\x00\x1c\x00.\x00&\x00\n\x00\x02\x00\x17\x00\x13\x00\x16\x00\x1b\x00\r\x00\x14\x00\x1c\x00\x07\x00\x05\x00\x17\x00\x19\x00"\x00 \x00\x1a\x00\x1d\x00\x1f\x00\x12\x00\x0b\x00\x1a\x00)\x00\x1b\x00\t\x00\x08\x00\x17\x00\x1e\x00\x14\x00\x12\x00 ,\x00\x1d\x00\n\x00\x15\x00\x17\x00\x0e\x00\x18\x00\x16\x00\x0b\x00\x0e\x00\x19\x00!\x00\x1c\x00\x10\x00\x12\x00\x18\x00\x19\x00\x1e\x00\x19\x00\x02\x00\x06\x00"\x00$\x00\x1e\x00\x1a\x00\x13\x00\x0e\x00\x0f\x00\x0c\x00\x11\x00\x17\x00\x17\x00\x ...

# %%
dataset.pixel_array
# Out:
# array([[38, 33, 15, ...,  0,  0,  0],
#        [27, 44, 29, ...,  0,  0,  0],
#        [ 5, 31, 46, ...,  0,  0,  0],
#        ...,
#        [13, 24, 19, ...,  0,  0,  0],
#        [19, 15, 16, ...,  0,  0,  0],
#        [ 8, 13, 28, ...,  0,  0,  0]], dtype=uint16)

# %%
dataset
# Out:
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'AXIAL', 'CT_SOM5 SPI']
# (0008, 0016) SOP Class UID                       UI: CT Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.3.12.2.1107.5.1.4.73429.30000018062007452632600012371
# (0008, 0020) Study Date                          DA: '20180620'
# (0008, 0021) Series Date                         DA: '20180620'
# (0008, 0022) Acquisition Date                    DA: '20180620'
# (0008, 0023) Content Date                        DA: '20180620'
# (0008, 002a) Acquisition DateTime                DT: '20180620131120.556000'
# (0008, 0030) Study Time                          TM: '130540.645000'
# (0008, 0031) Series Time                         TM: '131725.908000'
# (0008, 0032) Acquisition Time                    TM: '131120.556000'
# (0008, 0033) Content Time                        TM: '131120.556000'
# (0008, 0050) Accession Number                    SH: ''
# (0008, 0060) Modality                            CS: 'CT'
# (0008, 0070) Manufacturer                        LO: 'SIEMENS'
# (0008, 0080) Institution Name                    LO: 'MC UDP RK ASTANA'
# (0008, 0081) Institution Address                 ST: 'Orynbor\r\nAstana\r\nDistrict\r\nKZ'
# (0008, 0090) Referring Physician's Name          PN: ''
# (0008, 1010) Station Name                        SH: 'CTAWP73429'
# (0008, 1030) Study Description                   LO: 'Abdomen^ABDOMEN_MULTI (Adult)'
# (0008, 103e) Series Description                  LO: 'Non Contrast  1.5  B30f'
# (0008, 1090) Manufacturer's Model Name           LO: 'SOMATOM Definition Flash'
# (0008, 1111)  Referenced Performed Procedure Step Sequence   1 item(s) ----
#    (0008, 1150) Referenced SOP Class UID            UI: Modality Performed Procedure Step SOP Class
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.73429.30000018062007431046800000011
#    ---------
# (0008, 1140)  Referenced Image Sequence   1 item(s) ----
#    (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.73429.30000018062007065205300001763
#    ---------
# (0008, 2112)  Source Image Sequence   1 item(s) ----
#    (0008, 1150) Referenced SOP Class UID            UI: 1.3.12.2.1107.5.9.1
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.73429.30000018062007433640900000066
#    ---------
# (0008, 3010) Irradiation Event UID               UI: 1.3.12.2.1107.5.1.4.73429.30000018062007433640900000066
# (0009, 0010) Private Creator                     LO: 'SIEMENS CT VA1 DUMMY'
# (0010, 0010) Patient's Name                      PN: 'EFREMOV   SERGEY  ALEXEEVICH^VIPROMID370-85ML'
# (0010, 0020) Patient ID                          LO: 'PL AMB'
# (0010, 0030) Patient's Birth Date                DA: '19600821'
# (0010, 0040) Patient's Sex                       CS: 'M'
# (0010, 1010) Patient's Age                       AS: '057Y'
# (0018, 0015) Body Part Examined                  CS: 'ABDOMEN'
# (0018, 0050) Slice Thickness                     DS: "1.5"
# (0018, 0060) KVP                                 DS: "100"
# (0018, 0090) Data Collection Diameter            DS: "500"
# (0018, 1000) Device Serial Number                LO: '73429'
# (0018, 1020) Software Version(s)                 LO: 'syngo CT 2012B'
# (0018, 1030) Protocol Name                       LO: 'ABDOMEN_MULTI'
# (0018, 1100) Reconstruction Diameter             DS: "364"
# (0018, 1110) Distance Source to Detector         DS: "1085.6"
# (0018, 1111) Distance Source to Patient          DS: "595"
# (0018, 1120) Gantry/Detector Tilt                DS: "0"
# (0018, 1130) Table Height                        DS: "138"
# (0018, 1140) Rotation Direction                  CS: 'CW'
# (0018, 1150) Exposure Time                       IS: "500"
# (0018, 1151) X-Ray Tube Current                  IS: "316"
# (0018, 1152) Exposure                            IS: "263"
# (0018, 1160) Filter Type                         SH: 'WEDGE_3'
# (0018, 1170) Generator Power                     IS: "27"
# (0018, 1190) Focal Spot(s)                       DS: "1.2"
# (0018, 1200) Date of Last Calibration            DA: '20180620'
# (0018, 1201) Time of Last Calibration            TM: '081243.000000'
# (0018, 1210) Convolution Kernel                  SH: 'B30f'
# (0018, 5100) Patient Position                    CS: 'HFS'
# (0018, 9306) Single Collimation Width            FD: 1.2
# (0018, 9307) Total Collimation Width             FD: 38.4
# (0018, 9309) Table Speed                         FD: 46.0
# (0018, 9310) Table Feed per Rotation             FD: 23.0
# (0018, 9311) Spiral Pitch Factor                 FD: 0.6
# (0018, 9313) Data Collection Center (Patient)    FD: [0.35546875, -137.64453125, -171.8]
# (0018, 9318) Reconstruction Target Center (Patie FD: [13.35546875, -137.64453125, -171.8]
# (0018, 9323) Exposure Modulation Type            CS: 'XYZ_EC'
# (0018, 9324) Estimated Dose Saving               FD: 47.5111
# (0018, 9345) CTDIvol                             FD: 11.10374099478261
# (0018, 9346)  CTDI Phantom Type Code Sequence   1 item(s) ----
#    (0008, 0100) Code Value                          SH: '113691'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'IEC Body Dosimetry Phantom'
#    ---------
# (0018, 9352) Calcium Scoring Mass Factor Device  FL: [0.6430000066757202, 0.6710000038146973, 0.6980000138282776]
# (0019, 0010) Private Creator                     LO: 'SIEMENS CT VA0  COAD'
# (0019, 1090) [Osteo Offset]                      DS: "0"
# (0019, 1092) [Osteo Regression Line Slope]       DS: "0.9179"
# (0019, 1093) [Osteo Regression Line Intercept]   DS: "-0.21"
# (0019, 1096) [Osteo Phantom Number]              IS: "0"
# (0019, 10b0) [Feed per Rotation]                 DS: "23"
# (0020, 000d) Study Instance UID                  UI: 1.3.12.2.1107.5.1.4.73429.30000018062007220895300000034
# (0020, 000e) Series Instance UID                 UI: 1.3.12.2.1107.5.1.4.73429.30000018062007452632600012253
# (0020, 0010) Study ID                            SH: '1'
# (0020, 0011) Series Number                       IS: "4"
# (0020, 0012) Acquisition Number                  IS: "2"
# (0020, 0013) Instance Number                     IS: "118"
# (0020, 0032) Image Position (Patient)            DS: ['-168.64453125', '-319.64453125', '-171.8']
# (0020, 0037) Image Orientation (Patient)         DS: ['1', '0', '0', '0', '1', '0']
# (0020, 0052) Frame of Reference UID              UI: 1.3.12.2.1107.5.1.4.73429.30000018062007433640900000064
# (0020, 1040) Position Reference Indicator        LO: ''
# (0020, 1041) Slice Location                      DS: "-171.8"
# (0020, 4000) Image Comments                      LT: ''
# (0021, 0010) Private Creator                     LO: 'SIEMENS MED'
# (0021, 1011) [Target]                            DS: ['13', '0']
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0010) Rows                                US: 512
# (0028, 0011) Columns                             US: 512
# (0028, 0030) Pixel Spacing                       DS: ['0.7109375', '0.7109375']
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 12
# (0028, 0102) High Bit                            US: 11
# (0028, 0103) Pixel Representation                US: 0
# (0028, 0106) Smallest Image Pixel Value          US: 0
# (0028, 0107) Largest Image Pixel Value           US: 2532
# (0028, 1050) Window Center                       DS: ['40', '300']
# (0028, 1051) Window Width                        DS: ['305', '1500']
# (0028, 1052) Rescale Intercept                   DS: "-1024"
# (0028, 1053) Rescale Slope                       DS: "1"
# (0028, 1054) Rescale Type                        LO: 'HU'
# (0028, 1055) Window Center & Width Explanation   LO: ['WINDOW1', 'WINDOW2']
# (0029, 0010) Private Creator                     LO: 'SIEMENS CSA HEADER'
# (0029, 0011) Private Creator                     LO: 'SIEMENS MEDCOM HEADER'
# (0029, 1008) [CSA Image Header Type]             CS: 'SOM 5'
# (0029, 1009) [CSA Image Header Version]          LO: 'VA10A 971201'
# (0029, 1010) [CSA Image Header Info]             OB: Array of 1326 elements
# (0029, 1140)  [Application Header Sequence]   2 item(s) ----
#    (0029, 0010) Private Creator                     LO: 'SIEMENS MEDCOM HEADER'
#    (0029, 1041) [Application Header Type]           CS: 'VIA_CARE_KV_WIND'
#    (0029, 1042) [Application Header ID]             LO: 'ORIG WINDOW VALUES FROM CAREKV'
#    (0029, 1043) [Application Header Version]        LO: 'V1 20120914'
#    (0029, 1044) [Application Header Info]           OB: b'4\x000\x00#\x003\x000\x000\x00\x00\x00'
#    ---------
#    (0029, 0010) Private Creator                     LO: 'SIEMENS MEDCOM HEADER'
#    (0029, 1041) [Application Header Type]           CS: 'SOM 5 TPOS'
#    (0029, 1042) [Application Header ID]             LO: 'SOM 5 NULLPOSITION'
#    (0029, 1043) [Application Header Version]        LO: 'VB10A 20030626'
#    (0029, 1044) [Application Header Info]           OB: b'-000010500\x00\x00'
#    ---------
# (0040, 0244) Performed Procedure Step Start Date DA: '20180620'
# (0040, 0245) Performed Procedure Step Start Time TM: '130540.664000'
# (0040, 0253) Performed Procedure Step ID         SH: 'CT20180620130540'
# (7fe0, 0010) Pixel Data                          OW: Array of 524288 elements
