# %%
from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import export_graphviz

iris = load_iris()
X = iris.data[:, 2:]
y = iris.target

tree_clf = DecisionTreeClassifier(max_depth=6)
tree_clf.fit(X, y)

export_graphviz(tree_clf, out_file=("iris_tree.dot"), feature_names=iris.feature_names[2:], class_names=iris.target_names, filled=True)

# %%
# --- graphviz
# https://dreampuf.github.io/GraphvizOnline/#digraph%20Tree%20%7B%0D%0Anode%20%5Bshape%3Dbox%2C%20style%3D%22filled%22%2C%20color%3D%22black%22%5D%20%3B%0D%0A0%20%5Blabel%3D%22petal%20width%20(cm)%20%3C%3D%200.8%5Cngini%20%3D%200.667%5Cnsamples%20%3D%20150%5Cnvalue%20%3D%20%5B50%2C%2050%2C%2050%5D%5Cnclass%20%3D%20setosa%22%2C%20fillcolor%3D%22%23ffffff%22%5D%20%3B%0D%0A1%20%5Blabel%3D%22gini%20%3D%200.0%5Cnsamples%20%3D%2050%5Cnvalue%20%3D%20%5B50%2C%200%2C%200%5D%5Cnclass%20%3D%20setosa%22%2C%20fillcolor%3D%22%23e58139%22%5D%20%3B%0D%0A0%20-%3E%201%20%5Blabeldistance%3D2.5%2C%20labelangle%3D45%2C%20headlabel%3D%22True%22%5D%20%3B%0D%0A2%20%5Blabel%3D%22petal%20width%20(cm)%20%3C%3D%201.75%5Cngini%20%3D%200.5%5Cnsamples%20%3D%20100%5Cnvalue%20%3D%20%5B0%2C%2050%2C%2050%5D%5Cnclass%20%3D%20versicolor%22%2C%20fillcolor%3D%22%23ffffff%22%5D%20%3B%0D%0A0%20-%3E%202%20%5Blabeldistance%3D2.5%2C%20labelangle%3D-45%2C%20headlabel%3D%22False%22%5D%20%3B%0D%0A3%20%5Blabel%3D%22petal%20length%20(cm)%20%3C%3D%204.95%5Cngini%20%3D%200.168%5Cnsamples%20%3D%2054%5Cnvalue%20%3D%20%5B0%2C%2049%2C%205%5D%5Cnclass%20%3D%20versicolor%22%2C%20fillcolor%3D%22%234de88e%22%5D%20%3B%0D%0A2%20-%3E%203%20%3B%0D%0A4%20%5Blabel%3D%22petal%20width%20(cm)%20%3C%3D%201.65%5Cngini%20%3D%200.041%5Cnsamples%20%3D%2048%5Cnvalue%20%3D%20%5B0%2C%2047%2C%201%5D%5Cnclass%20%3D%20versicolor%22%2C%20fillcolor%3D%22%233de684%22%5D%20%3B%0D%0A3%20-%3E%204%20%3B%0D%0A5%20%5Blabel%3D%22gini%20%3D%200.0%5Cnsamples%20%3D%2047%5Cnvalue%20%3D%20%5B0%2C%2047%2C%200%5D%5Cnclass%20%3D%20versicolor%22%2C%20fillcolor%3D%22%2339e581%22%5D%20%3B%0D%0A4%20-%3E%205%20%3B%0D%0A6%20%5Blabel%3D%22gini%20%3D%200.0%5Cnsamples%20%3D%201%5Cnvalue%20%3D%20%5B0%2C%200%2C%201%5D%5Cnclass%20%3D%20virginica%22%2C%20fillcolor%3D%22%238139e5%22%5D%20%3B%0D%0A4%20-%3E%206%20%3B%0D%0A7%20%5Blabel%3D%22petal%20width%20(cm)%20%3C%3D%201.55%5Cngini%20%3D%200.444%5Cnsamples%20%3D%206%5Cnvalue%20%3D%20%5B0%2C%202%2C%204%5D%5Cnclass%20%3D%20virginica%22%2C%20fillcolor%3D%22%23c09cf2%22%5D%20%3B%0D%0A3%20-%3E%207%20%3B%0D%0A8%20%5Blabel%3D%22gini%20%3D%200.0%5Cnsamples%20%3D%203%5Cnvalue%20%3D%20%5B0%2C%200%2C%203%5D%5Cnclass%20%3D%20virginica%22%2C%20fillcolor%3D%22%238139e5%22%5D%20%3B%0D%0A7%20-%3E%208%20%3B%0D%0A9%20%5Blabel%3D%22petal%20length%20(cm)%20%3C%3D%205.45%5Cngini%20%3D%200.444%5Cnsamples%20%3D%203%5Cnvalue%20%3D%20%5B0%2C%202%2C%201%5D%5Cnclass%20%3D%20versicolor%22%2C%20fillcolor%3D%22%239cf2c0%22%5D%20%3B%0D%0A7%20-%3E%209%20%3B%0D%0A10%20%5Blabel%3D%22gini%20%3D%200.0%5Cnsamples%20%3D%202%5Cnvalue%20%3D%20%5B0%2C%202%2C%200%5D%5Cnclass%20%3D%20versicolor%22%2C%20fillcolor%3D%22%2339e581%22%5D%20%3B%0D%0A9%20-%3E%2010%20%3B%0D%0A11%20%5Blabel%3D%22gini%20%3D%200.0%5Cnsamples%20%3D%201%5Cnvalue%20%3D%20%5B0%2C%200%2C%201%5D%5Cnclass%20%3D%20virginica%22%2C%20fillcolor%3D%22%238139e5%22%5D%20%3B%0D%0A9%20-%3E%2011%20%3B%0D%0A12%20%5Blabel%3D%22petal%20length%20(cm)%20%3C%3D%204.85%5Cngini%20%3D%200.043%5Cnsamples%20%3D%2046%5Cnvalue%20%3D%20%5B0%2C%201%2C%2045%5D%5Cnclass%20%3D%20virginica%22%2C%20fillcolor%3D%22%23843de6%22%5D%20%3B%0D%0A2%20-%3E%2012%20%3B%0D%0A13%20%5Blabel%3D%22gini%20%3D%200.444%5Cnsamples%20%3D%203%5Cnvalue%20%3D%20%5B0%2C%201%2C%202%5D%5Cnclass%20%3D%20virginica%22%2C%20fillcolor%3D%22%23c09cf2%22%5D%20%3B%0D%0A12%20-%3E%2013%20%3B%0D%0A14%20%5Blabel%3D%22gini%20%3D%200.0%5Cnsamples%20%3D%2043%5Cnvalue%20%3D%20%5B0%2C%200%2C%2043%5D%5Cnclass%20%3D%20virginica%22%2C%20fillcolor%3D%22%238139e5%22%5D%20%3B%0D%0A12%20-%3E%2014%20%3B%0D%0A%7D

# %%
from matplotlib.colors import ListedColormap
import numpy as np
import matplotlib.pyplot as plt


def plot_decision_boundary(clf, X, y, axes=[0, 7.5, 0, 3], iris=True, legend=False, plot_training=True):
    x1s = np.linspace(axes[0], axes[1], 100)
    x2s = np.linspace(axes[2], axes[3], 100)
    x1, x2 = np.meshgrid(x1s, x2s)
    X_new = np.c_[x1.ravel(), x2.ravel()]
    y_pred = clf.predict(X_new).reshape(x1.shape)
    custom_cmap = ListedColormap(['#fafab0','#9898ff','#a0faa0'])
    plt.contourf(x1, x2, y_pred, alpha=0.3, cmap=custom_cmap)
    if not iris:
        custom_cmap2 = ListedColormap(['#7d7d58','#4c4c7f','#507d50'])
        plt.contour(x1, x2, y_pred, cmap=custom_cmap2, alpha=0.8)
    if plot_training:
        plt.plot(X[:, 0][y==0], X[:, 1][y==0], "yo", label="Iris-Setosa")
        plt.plot(X[:, 0][y==1], X[:, 1][y==1], "bs", label="Iris-Versicolor")
        plt.plot(X[:, 0][y==2], X[:, 1][y==2], "g^", label="Iris-Virginica")
        plt.axis(axes)
    if iris:
        plt.xlabel("Petal length", fontsize=14)
        plt.ylabel("Petal width", fontsize=14)
    else:
        plt.xlabel(r"$x_1$", fontsize=18)
        plt.ylabel(r"$x_2$", fontsize=18, rotation=0)
    if legend:
        plt.legend(loc="lower right", fontsize=14)

plot_decision_boundary(tree_clf, X, y)
plt.show()

# %%
from sklearn.datasets import make_moons
from sklearn.model_selection import train_test_split

X, y = make_moons(n_samples = 1000, noise = 0.4)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
plt.plot(X[:, 0][y == 0], X[:, 1][y == 0], "yo")
plt.plot(X[:, 0][y == 1], X[:, 1][y == 1], "bo")

# %%
from sklearn.model_selection import GridSearchCV

params = {'max_leaf_nodes': list(range(2, 100)), 'min_samples_split': [2, 3, 4]}
grid_search_cv = GridSearchCV(DecisionTreeClassifier(), params, n_jobs=-1, verbose=1, cv=3)
grid_search_cv.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 294 candidates, totalling 882 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  68 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-1)]: Done 882 out of 882 | elapsed:    0.5s finished
# GridSearchCV(cv=3, error_score='raise-deprecating',
#              estimator=DecisionTreeClassifier(class_weight=None,
#                                               criterion='gini', max_depth=None,
#                                               max_features=None,
#                                               max_leaf_nodes=None,
#                                               min_impurity_decrease=0.0,
#                                               min_impurity_split=None,
#                                               min_samples_leaf=1,
#                                               min_samples_split=2,
#                                               min_weight_fraction_leaf=0.0,
# ...

# %%
grid_search_cv.best_estimator_
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#                        max_features=None, max_leaf_nodes=4,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=None, splitter='best')

# %%
from sklearn.metrics import accuracy_score

y_pred = grid_search_cv.best_estimator_.predict(X_test)
accuracy_score(y_pred, y_test)
# Out:
# 0.85

# %%
plot_decision_boundary(grid_search_cv.best_estimator_, X, y, axes=[-3, 3, -2, 2], plot_training=True)
plt.show()

# %%
from sklearn.model_selection import ShuffleSplit

n_trees = 1000
n_instances = 100

mini_sets = []

rs = ShuffleSplit(n_splits=n_trees, train_size=n_instances)

for mini_train_index, mini_test_index in rs.split(X):
    X_mini_train = X[mini_train_index]
    y_mini_train = y[mini_train_index]
    X_mini_test  = X[mini_test_index]
    y_mini_test  = y[mini_test_index]
    mini_sets.append((X_mini_train, y_mini_train, X_mini_test, y_mini_test))

# %%
from sklearn.base import clone

forest = [clone(grid_search_cv.best_estimator_) for _ in range(n_trees)]

accuracy_scores = []

for tree, (X_mini_train, y_mini_train, X_mini_test, y_mini_test) in zip(forest, mini_sets):
        tree.fit(X_mini_train, y_mini_train)
        
        y_pred = tree.predict(X_test)
        accuracy_scores.append(accuracy_score(y_pred, y_test))
        
np.mean(accuracy_scores)
# Out:
# 0.8372600000000001

# %%
Y_pred = np.empty([n_trees, len(X_test)])

for idx, tree in enumerate(forest):
    Y_pred[idx] = tree.predict(X_test)

# %%
from scipy.stats import mode

y_pred_majority_votes, n_votes = mode(Y_pred)

# %%
accuracy_score(y_pred_majority_votes[0], y_test)
# Out:
# 0.86
